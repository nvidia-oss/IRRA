# %% [markdown]
# <a href="https://colab.research.google.com/github/nvidia-oss/IRRA/blob/main/IRRA_pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/anosorae/IRRA.git
# Out:
# Cloning into 'IRRA'...
# remote: Enumerating objects: 145, done.
# remote: Counting objects: 100% (47/47), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 145 (delta 20), reused 22 (delta 8), pack-reused 98
# Receiving objects: 100% (145/145), 1.98 MiB | 12.60 MiB/s, done.
# Resolving deltas: 100% (56/56), done.

# %%
! pwd
# Out:
# /content

# %%
cd /content/IRRA
# Out:
# /content/IRRA

# %%
cd /content/IRRA/data
# Out:
# /content/IRRA/data

# %%
# !cp /content/drive/MyDrive/ICFG-PDES.zip ./

# %%
# !unzip ./ICFG-PDES.zip -d ./
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
#   inflating: ./ICFG-PEDES/imgs/train/0879/0879_009_14_0114noon_0280_5.jpg
#   inflating: ./ICFG-PEDES/imgs/train/0879/0879_017_15_0114noon_0339_1_ex.jpg
#   inflating: ./ICFG-PEDES/imgs/train/0879/0879_008_14_0114noon_0278_2.jpg
#   inflating: ./ICFG-PEDES/imgs/train/0879/0879_015_15_0114noon_0338_0_ex.jpg
#   inflating: ./ICFG-PEDES/imgs/train/0879/0879_019_15_0114noon_0340_3_ex.jpg
#   inflating: ./ICFG-PEDES/imgs/train/0879/0879_013_14_0114noon_0286_1.jpg
#   inflating: ./ICFG-PEDES/imgs/train/0879/0879_012_14_0114noon_0285_0_ex.jpg
#   inflating: ./ICFG-PEDES/imgs/train/0879/0879_004_05_0114noon_0257_3_ex.jpg
#   inflating: ./ICFG-PEDES/imgs/train/0879/0879_006_05_0114noon_0266_3_ex.jpg
#    creating: ./ICFG-PEDES/imgs/train/0277/
#   inflating: ./ICFG-PEDES/imgs/train/0277/0277_011_11_0303afternoon_1372_1.jpg
#   inflating: ./ICFG-PEDES/imgs/train/0277/0277_012_11_0303afternoon_1373_1.jpg
# ...

# %%
! pwd

cd ..
# Out:
#   File "<ipython-input-14-8fc8992becaf>", line 3
#     cd ..
#         ^
# SyntaxError: invalid syntax

# %%
cd ..
# Out:
# /content/IRRA

# %%
# !python test.py
# Out:
# 2024-04-09 03:27:11.756068: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-09 03:27:11.756163: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-09 03:27:11.761203: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-09 03:27:13.862295: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...

# %%
# !pip install ftfy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.4/54.4 kB 908.2 kB/s eta 0:00:00
# ...
